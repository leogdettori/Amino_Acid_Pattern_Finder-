# %%
#All 4 modules  (Using Slice_Sequence)

# ----------------------------------------------------------------------------------------- # Required Specs.:
IUPRED_results_folder = "C:/Users/leogd/Desktop/FMRP_test/iupred/"

output = "C:/Users/leogd/Desktop/FMRP_test/"

tolerance = 10

min_IDR_length = 30

threshold = 0.5

# ----- # Slices Module Specs.:  (use window = "none" and step ="none" when not using this module)
#Specifies length of the peptide slices that will be analyzed
window = 40
#Specifies the step at which the window will be moved throughout the sequence
step = 1

# ----- # Recommended Clusters:
#Cluster 5 (All Positives Together, A is flexible):
Cluster_Code_5 = ['1','2','3','4','5','6']
Cluster_5 = ['Y','W','F'],['K','R','H'],['N','Q'],['D','E'],['G','S','P','T','C','A'],['I','L','V','M']

# ----- # Clusters Specs.:
clusters = Cluster_5
cluster_code = Cluster_Code_5
cluster_name = "Cluster_5"


# ----- # Optional Specs.:
#list_file_location = 'C:/Users/leogd/Examples_IDRs_20/Coded_Lists__Cluster_5/'
#output_path = "C:/Users/leogd/Examples_list"  #For List_Generator
#output_location = "input"  #For Pattern_Finder
plots = "off"  #For Pattern_Finder


# ----------------------------------------------------------------------------------------- # Importing Libraries:
from nested_Extract_IDRs_from_IUPRED_as_function import *
from nested_Coded_List_Generator_as_function import *
from nested_amino_acid_pattern_finder_extended_LD_07302021 import *
from nested_Slice_Seq_as_function import *
# ----------------------------------------------------------------------------------------- # Program Pipeline:

#Extract_IDRs('IUPRED_results_folder', 'tolerance', 'min_IDR_length', 'threshold', 'output')
input_path = Extract_IDRs(IUPRED_results_folder, tolerance, min_IDR_length, threshold, output)

#Slice_Sequence('for multiple runs:Extract_IDRs_results_folder_same_that_contains_summary.txt or for single run: single_folder_full_of_fasta_files','window_size','step_size')
Slice_Sequence(input_path, window, step)

#Coded_List_Generator('for multiple runs:Extract_IDRs_results_folder_same_that_contains_summary.txt or for single run: single_folder_full_of_fasta_files', 'cluster_name', 'clusters', 'cluster_code', 'output_path')
list_file_location = Coded_List_Generator(input_path, cluster_name, clusters, cluster_code, window, step)#, output_path)

#Amino_Acid_Pattern_Finder_Extended('list_file_location', 'plots', 'output_location')
Amino_Acid_Pattern_Finder_Extended(list_file_location, plots)#, output_location)

# %%
#3 modules  (Skipping Extract_IDRs_from_IUPRED)

# ----------------------------------------------------------------------------------------- # Required Specs.:
fasta_folder = "C:/Users/leogd/Desktop/Slice_FMRP_C_IDR/fasta"

output = "C:/Users/leogd/Desktop/Slice_FMRP_C_IDR/"

# ----- # Slices Module Specs.:  (use window = "none" and step ="none" when not using this module)
#Specifies length of the peptide slices that will be analyzed
window = 72
#Specifies the step at which the window will be moved throughout the sequence
step = 1

# ----- # Recommended Clusters:
#Cluster 5 (All Positives Together, A is flexible):
Cluster_Code_5 = ['1','2','3','4','5','6']
Cluster_5 = ['Y','W','F'],['K','R','H'],['N','Q'],['D','E'],['G','S','P','T','C','A'],['I','L','V','M']

# ----- # Clusters Specs.:
clusters = Cluster_5
cluster_code = Cluster_Code_5
cluster_name = "Cluster_5"


# ----- # Optional Specs.:
#list_file_location = 'C:/Users/leogd/Examples_IDRs_20/Coded_Lists__Cluster_5/'
#output_path = "C:/Users/leogd/Examples_list"  #For List_Generator
#output_location = "input"  #For Pattern_Finder
plots = "on"  #For Pattern_Finder


# ----------------------------------------------------------------------------------------- # Importing Libraries:
from nested_Coded_List_Generator_as_function import *
from nested_amino_acid_pattern_finder_extended_LD_07302021 import *
from nested_Slice_Seq_as_function import *
# ----------------------------------------------------------------------------------------- # Program Pipeline:

#Slice_Sequence('for multiple runs:Extract_IDRs_results_folder_same_that_contains_summary.txt or for single run: single_folder_full_of_fasta_files','window_size','step_size')
input_path = Slice_Sequence(fasta_folder, window, step)

#Coded_List_Generator('for multiple runs:Extract_IDRs_results_folder_same_that_contains_summary.txt or for single run: single_folder_full_of_fasta_files', 'cluster_name', 'clusters', 'cluster_code', 'output_path')
list_file_location = Coded_List_Generator(input_path, cluster_name, clusters, cluster_code, window, step, output)

#Amino_Acid_Pattern_Finder_Extended('list_file_location', 'plots', 'output_location')
Amino_Acid_Pattern_Finder_Extended(list_file_location, plots, output)

# %%
#3 modules
#skipping Slice_Sequence
# ----------------------------------------------------------------------------------------- #
from nested_Extract_IDRs_from_IUPRED_as_function import *
from nested_Coded_List_Generator_as_function import *
from nested_amino_acid_pattern_finder_extended_LD_07302021 import *

# ----------------------------------------------------------------------------------------- #
IUPRED_results_folder = "C:/Users/leogd/Desktop/Test_RBM3_C_IDR_length_no_slice/iupred"

output = "C:/Users/leogd/Desktop/Test_RBM3_C_IDR_length_no_slice/"

tolerance = 10

min_IDR_length = 72

threshold = 0.5

# ----- #
#Cluster 5 (All Positives Together, A is flexible):
Cluster_Code_5 = ['1','2','3','4','5','6']
Cluster_5 = ['Y','W','F'],['K','R','H'],['N','Q'],['D','E'],['G','S','P','T','C','A'],['I','L','V','M']
# ----- #

#input_path = 'C:/Users/leogd/Examples_IDRs_20/Extract_IDRs_Results__len_20_thr_0.5_tol_10/'
clusters = Cluster_5
cluster_code = Cluster_Code_5
cluster_name = "Cluster_5"
#output_path = "C:/Users/leogd/Examples_list"

# ----- #

#list_file_location = 'C:/Users/leogd/Examples_IDRs_20/Coded_Lists__Cluster_5/'

#output_location = "input"


# ----------------------------------------------------------------------------------------- #

#Extract_IDRs('IUPRED_results_folder', 'tolerance', 'min_IDR_length', 'threshold', 'output')
input_path = Extract_IDRs(IUPRED_results_folder, tolerance, min_IDR_length, threshold, output)

#Coded_List_Generator('for multiple runs:Extract_IDRs_results_folder_same_that_contains_summary.txt or for single run: single_folder_full_of_fasta_files', 'cluster_name', 'clusters', 'cluster_code', 'output_path')
list_file_location = Coded_List_Generator(input_path, cluster_name, clusters, cluster_code)#, output_path)

#Amino_Acid_Pattern_Finder_Extended('list_file_location', 'output_location')
Amino_Acid_Pattern_Finder_Extended(list_file_location)#, output_location)

# %%
#2 modules
#skipping extract IDRs from IUPRED
# ----------------------------------------------------------------------------------------- #
from nested_Coded_List_Generator_as_function import *
from nested_amino_acid_pattern_finder_extended_LD_07302021 import *

# ----------------------------------------------------------------------------------------- #
#Cluster 5 (All Positives Together, A is flexible):
Cluster_Code_5 = ['1','2','3','4','5','6']
Cluster_5 = ['Y','W','F'],['K','R','H'],['N','Q'],['D','E'],['G','S','P','T','C','A'],['I','L','V','M']
# ----- #

input_path = 'C:/Users/leogd/Desktop/Test_FMRP_523_Ref/fasta'
clusters = Cluster_5
cluster_code = Cluster_Code_5
cluster_name = "Cluster_5"
output_path = "C:/Users/leogd/Desktop/Test_FMRP_523_Ref"

# ----- #

#list_file_location = 'C:/Users/leogd/Examples_IDRs_20/Coded_Lists__Cluster_5/'

#output_location = "input"

# ----------------------------------------------------------------------------------------- #

#Set the prgrom the following way: 
#Coded_List_Generator('for multiple runs:Extract_IDRs_results_folder_same_that_contains_summary.txt or for single run: single_folder_full_of_fasta_files', 'cluster_name', 'clusters', 'cluster_code', 'output_path')
list_file_location = Coded_List_Generator(input_path, cluster_name, clusters, cluster_code, output_path)

#Amino_Acid_Pattern_Finder_Extended('list_file_location', 'output_location')
Amino_Acid_Pattern_Finder_Extended(list_file_location)#, output_location)

# %%
#Options below are outdated:

# %%
#Standalone module
# ----------------------------------------------------------------------------------------- #
from nested_Extract_IDRs_from_IUPRED_as_function import *

# ----------------------------------------------------------------------------------------- #

#IUPRED_results = "C:/Users/leogd/Desktop/Review_Paper/Analyses/IUPred2A_Analysis/IUPred2A_Results_Hydrolases_67_proteins_list.result"
IUPRED_results_folder = "C:/Users/leogd/Desktop/Review_Paper/Analyses/IUPred2A_Analysis/Examples"

output = "C:/Users/leogd/Examples_IDRs_40/"

tolerance = 10

min_IDR_length = 40

threshold = 0.5

# ----------------------------------------------------------------------------------------- #

#Set the prgrom the following way: 
#Extract_IDRs('IUPRED_results_folder', 'tolerance', 'min_IDR_length', 'threshold', 'output')
Extract_IDRs(IUPRED_results_folder, tolerance, min_IDR_length, threshold, output)

# %%
#Standalone module
# ----------------------------------------------------------------------------------------- #
from nested_Coded_List_Generator_as_function import *

# ----------------------------------------------------------------------------------------- #
#Cluster 5 (All Positives Together, A is flexible):
Cluster_Code_5 = ['1','2','3','4','5','6']
Cluster_5 = ['Y','W','F'],['K','R','H'],['N','Q'],['D','E'],['G','S','P','T','C','A'],['I','L','V','M']


input_path = 'C:/Users/leogd/Desktop/Review_Paper/Lists/New_Readers_single_Fastas/'
clusters = Cluster_5
cluster_code = Cluster_Code_5
cluster_name = "Cluster_5"
output_path = "C:/Users/leogd/New_Readers_list_FL"

# ----------------------------------------------------------------------------------------- #

#Set the prgrom the following way: 
#Coded_List_Generator('for multiple runs:Extract_IDRs_results_folder_same_that_contains_summary.txt or for single run: single_folder_full_of_fasta_files', 'cluster_name', 'clusters', 'cluster_code', 'output_path')
list_file_location = Coded_List_Generator(input_path, cluster_name, clusters, cluster_code, output_path)

# %%
#Standalone module
# ----------------------------------------------------------------------------------------- #
from nested_amino_acid_pattern_finder_extended_LD_02242021 import *

# ----------------------------------------------------------------------------------------- #

list_file_location = 'C:/Users/leogd/New_Readers_list_FL/Coded_Lists__Cluster_5/'

#output_location = "input"

# ----------------------------------------------------------------------------------------- #

#Set the prgrom the following way: 
#Amino_Acid_Pattern_Finder_Extended('list_file_location', 'output_location')
Amino_Acid_Pattern_Finder_Extended(list_file_location)#, output_location)
